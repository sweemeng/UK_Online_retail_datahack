# %% [markdown]
# ## Setup dependency

# %%
import pandas

# %%
from sklearn import cluster

# %%
from matplotlib import pyplot

# %%
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# This is important, this is to make the dataviz work on notebook

# %%
# %matplotlib notebook

# %% [markdown]
# Now to load the customer data.

# %%
cust_df = pandas.read_excel("customers.xlsx", index_col="CustomerID")

# %%
temp = cust_df[['Frequency', 'Recency', 'Monetary', 'FirstPurchase']]

# %% [markdown]
# Now we cluster.

# %%
centroid, labels, inertia = cluster.k_means(temp, n_clusters=5)

# %%
temp["cluster"] = labels
# Out:
# /home/sweemeng/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Now we load the chart

# %%
fig = pyplot.figure()
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">

# %%
ax = Axes3D(fig)

# %%
ax.scatter(temp["Recency"], temp["Monetary"], temp["Frequency"], c=temp["cluster"])

# %%
ax.set_xlabel("Recency")

# %%
ax.set_ylabel("Monetary")

# %%
ax.set_zlabel("Frequency")

# %%
pyplot.show() # You don't actually need it on notebook, but useful for script

# %% [markdown]
# Hack further

# %%
temp2= cust_df[['Frequency', 'Recency', 'Monetary', 'FirstPurchase']]

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier()

# %%
clf = clf.fit(temp2, labels)

# %%
import graphviz

# %%
dot_data = tree.export_graphviz(clf, out_file=None,
                               )

# %%
graph = graphviz.Source(dot_data)

# %%
graph.render("uk_retail")
# Out:
# 'uk_retail.pdf'

# %%
cluster0=temp[temp["cluster"] == 0]

# %%
cluster1=temp[temp["cluster"] == 1]

# %%
cluster2=temp[temp["cluster"] ==2]

# %%
cluster3=temp[temp["cluster"] ==3]

# %%
cluster4=temp[temp["cluster"] ==4]

# %%
cluster0.columns
# Out:
# Index(['Frequency', 'Recency', 'Monetary', 'FirstPurchase', 'cluster'], dtype='object')

# %%
print(cluster0["Frequency"].median())
print(cluster0["Monetary"].median())
print(cluster0["Recency"].median())
print(cluster0["FirstPurchase"].median())
print(cluster0.count())
# Out:
# 37.0
# 594.53
# 2.0
# 8.0
# Frequency        4072
# Recency          4072
# Monetary         4072
# FirstPurchase    4072
# cluster          4072
# dtype: int64

# %%
print(cluster1["Frequency"].median())
print(cluster1["Monetary"].median())
print(cluster1["Recency"].median())
print(cluster1["FirstPurchase"].median())
print(cluster1.count())
# Out:
# 433.0
# 256438.49
# 0.0
# 12.0
# Frequency        3
# Recency          3
# Monetary         3
# FirstPurchase    3
# cluster          3
# dtype: int64

# %%
print(cluster2["Frequency"].median())
print(cluster2["Monetary"].median())
print(cluster2["Recency"].median())
print(cluster2["FirstPurchase"].median())
print(cluster2.count())
# Out:
# 1248.0
# 118554.795
# 0.5
# 12.0
# Frequency        4
# Recency          4
# Monetary         4
# FirstPurchase    4
# cluster          4
# dtype: int64

# %%
print(cluster3["Frequency"].median())
print(cluster3["Monetary"].median())
print(cluster3["Recency"].median())
print(cluster3["FirstPurchase"].median())
print(cluster3.count())
# Out:
# 280.0
# 6746.879999999999
# 1.0
# 12.0
# Frequency        266
# Recency          266
# Monetary         266
# FirstPurchase    266
# cluster          266
# dtype: int64

# %%
print(cluster4["Frequency"].median())
print(cluster4["Monetary"].median())
print(cluster4["Recency"].median())
print(cluster4["FirstPurchase"].median())
print(cluster4.count())
# Out:
# 399.0
# 33805.69
# 0.0
# 12.0
# Frequency        27
# Recency          27
# Monetary         27
# FirstPurchase    27
# cluster          27
# dtype: int64

# %%
cust_df.columns
# Out:
# Index(['Country', 'Frequency', 'FirstPurchase', 'Recency', 'Monetary', 'Min',
#        'Max', 'Median'],
#       dtype='object')

# %%
fig = pyplot.figure()
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">

# %%
ax = Axes3D(fig)

# %%
ax.scatter(cluster0["Recency"], cluster0["Monetary"], cluster0["Frequency"], c=cluster0["cluster"])

# %%
ax.set_xlabel("Recency")

# %%
ax.set_ylabel("Monetary")

# %%
ax.set_zlabel("Frequency")

# %%
fig = pyplot.figure()
ax = Axes3D(fig)
ax.scatter(cluster1["Recency"], cluster1["Monetary"], cluster1["Frequency"], c=cluster1["cluster"])
ax.set_xlabel("Recency")
ax.set_ylabel("Monetary")
ax.set_zlabel("Frequency")
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">

# %%
fig = pyplot.figure()
ax = Axes3D(fig)
ax.scatter(cluster2["Recency"], cluster2["Monetary"], cluster2["Frequency"], c=cluster2["cluster"])
ax.set_xlabel("Recency")
ax.set_ylabel("Monetary")
ax.set_zlabel("Frequency")
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">

# %%
fig = pyplot.figure()
ax = Axes3D(fig)
ax.scatter(cluster3["Recency"], cluster3["Monetary"], cluster3["Frequency"], c=cluster3["cluster"])
ax.set_xlabel("Recency")
ax.set_ylabel("Monetary")
ax.set_zlabel("Frequency")
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">

# %%
fig = pyplot.figure()
ax = Axes3D(fig)
ax.scatter(cluster4["Recency"], cluster4["Monetary"], cluster4["Frequency"], c=cluster4["cluster"])
ax.set_xlabel("Recency")
ax.set_ylabel("Monetary")
ax.set_zlabel("Frequency")
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">

# %%
for item in cluster0.index:
    print(cust_df["Country"][item])
# Out:
# United Kingdom
# Iceland
# Finland
# Italy
# Norway
# Norway
# Bahrain
# Spain
# Bahrain
# Portugal
# Austria
# Austria
# Belgium
# Unspecified
# Belgium
# Cyprus
# Denmark
# Cyprus
# Switzerland
# Denmark
# Austria
# Austria
# Finland
# Switzerland
# Switzerland
# Belgium
# Belgium
# Norway
# Belgium
# Switzerland
# Australia
# Australia
# Belgium
# Cyprus
# Australia
# Belgium
# Belgium
# Belgium
# Switzerland
# Belgium
# Belgium
# Belgium
# Denmark
# Finland
# Denmark
# Belgium
# Belgium
# Switzerland
# Denmark
# France
# Austria
# Belgium
# Switzerland
# Cyprus
# Spain
# Australia
# Belgium
# Australia
# Portugal
# Germany
# Germany
# Denmark
# Norway
# Australia
# Norway
# Norway
# France
# Spain
# Spain
# RSA
# Belgium
# Spain
# Belgium
# Spain
# Switzerland
# Austria
# Spain
# Cyprus
# Switzerland
# Switzerland
# Switzerland
# Switzerland
# Spain
# Belgium
# Belgium
# Belgium
# Germany
# Germany
# Germany
# Greece
# Germany
# Germany
# Sweden
# Spain
# France
# France
# ...

# %%
country = cust_df["Country"][cluster0.index]

# %%
country
# Out:
# CustomerID
# 12346    United Kingdom
# 12347           Iceland
# 12348           Finland
# 12349             Italy
# 12350            Norway
# 12352            Norway
# 12353           Bahrain
# 12354             Spain
# 12355           Bahrain
# 12356          Portugal
# 12358           Austria
# 12360           Austria
# 12361           Belgium
# 12363       Unspecified
# 12364           Belgium
# 12365            Cyprus
# 12367           Denmark
# 12370            Cyprus
# 12371       Switzerland
# 12372           Denmark
# 12373           Austria
# 12374           Austria
# 12375           Finland
# 12377       Switzerland
# 12378       Switzerland
# 12379           Belgium
# 12380           Belgium
# 12381            Norway
# 12383           Belgium
# 12384       Switzerland
#               ...
# 18245    United Kingdom
# 18246    United Kingdom
# 18248    United Kingdom
# 18249    United Kingdom
# 18250    United Kingdom
# 18251    United Kingdom
# 18252    United Kingdom
# ...

# %%
fig = pyplot.figure()
country[country!= "United Kingdom"].value_counts().plot(kind="bar")
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">

# %%
country3 = cust_df["Country"][cluster3.index]

# %%
fig = pyplot.figure()
country3[country3!= "United Kingdom"].value_counts().plot(kind="bar")
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">
